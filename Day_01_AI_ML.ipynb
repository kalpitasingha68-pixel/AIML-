# %% [markdown]
# Python3

# %%
# Build  a Calculator
# Concepts: Type Casting, Variable, Data Type, I/O, Comments
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Addition is:", a+b)
print(f"Addition is: {a+b}") # F-String (Very Crucial)
print(f"Subtraction is: {a-b}")
print(f"Multiplication is: {a*b}")
print(f"Division is: {a/b}")
# Out:
# Enter first number: 100
# Enter second number: 200
# Addition is: 300
# Addition is: 300
# Subtraction is: -100
# Multiplication is: 20000
# Division is: 0.5

# %%
name = input("Enter your name:")
age = int(input("Enter your age:"))
dept = input("Enter your department:")
print(f"My name is (name), age is (age) & the department is(dept)")
# Out:
# Enter your name:Kalpita
# Enter your age:21
# Enter your department:ECE
# My name is (name), age is (age) & the department is(dept)

# %%
# take two numbers and print their sum
a = float(input("Enter first number: "))
b = float(input("Enter another number: "))

print(a+b)
# Out:
# Enter first number: 10
# Enter another number: 0
# 10.0

# %%
#Take one float number and print it
a = float(input("Enter a number: "))
print(a)
# Out:
# Enter a number: 10
# 10.0

# %%
# Create varibales for name, salary, and , job role
name = input("Enter your name: ")
salary = float(input("Enter your salary: "))
job_role = input("Enter your job role: ")

print(f"Name is:{name}, salary is: {salary}, and job role is{job_role}")
# Out:
# Enter your name: Kalpi
# Enter your salary: 60000
# Enter your job role: Freelance AI Engineer
# Name is:Kalpi, salary is: 60000.0, and job role isFreelance AI Engineer

# %%
message = input("Enter a message:")

# %%
#Popular Data Types in Python

# List VS Tuple

roles = ["AI engineer", "Freelancer soft Developer", "Designer", "Tester"] #List
age = (18,19,20,22,23,24,25,40,60,) # tuple

# Set VS Dectionary

names = {"Alex", "Yuli"} # Set
ages ={"Alex": "Data scientist", "Yuli": "Freelancer AI Tutor"} #Dictionary

info = {
    "brand":
}
# Out:
#   File "/tmp/ipykernel_772/4033434828.py", line 14
#     "brand":
#            ^
# SyntaxError: expression expected after dictionary key and ':'

# %%
# lets check you're eligible for driving

name = int(input("Enter  your name: ")
)

if age>18:
    print("You can drive")
else:
    print("OOPs! You can't drive")
# Out:
# Enter  your name: kalpi
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_772/1345461693.py in <cell line: 0>()
#       1 # lets check you're eligible for driving
#       2
# ----> 3 name = int(input("Enter  your name: ")
#       4 )
#       5
#
# ValueError: invalid literal for int() with base 10: 'kalpi'

# %%
# if-else-elif statement  & Indentation

# Lets find greatest amon three numbers
# Logical operators; and, or, not
a =  int(input("enter a:"))
b =  int(input("enter b:"))
c =  int(input("enter c:"))

if a>b and a>c:
 print("a is the greatest")
elif b>a and b>c
    print("b is the greatest")
else:
      print("c is the greatest")
# Out:
#   File "/tmp/ipykernel_772/166883073.py", line 11
#     elif b>a and b>c
#                     ^
# SyntaxError: expected ':'

# %%
# Modules

import math

a =25

print(math.sqrt(a))
# Out:
# 5.0

# %%
# How can you print the current data & time?

import datatime

a = datatime.datetime.now()

print(a)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_772/2255107086.py in <cell line: 0>()
#       1 # How can you print the current data & time?
#       2
# ----> 3 import datatime
#       4
#       5 a = datatime.datetime.now()
#
# ModuleNotFoundError: No module named 'datatime'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# in future when we make projects we should use modules like this:
